# %%
import mglearn
# 은닉층이 1개인 인공신경망
mglearn.plots.plot_single_hidden_layer_graph()

# %%
# 은닉층이 2개인 인공신경망
mglearn.plots.plot_two_hidden_layer_graph()

# %%
from sklearn.datasets import make_moons

# noise 표준편차
X, y = make_moons(n_samples=100, noise=0.25, random_state=3)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=0)
# stratify=y :학습용 데이터와 검증용 데이터에서 각각의 타겟값들이 동일한 비율로 나타나도록 함

# %%
from sklearn.neural_network import MLPClassifier

model = MLPClassifier(random_state=0, max_iter=5000).fit(X_train, y_train)
# hidden_layer_sizes=(100,) , 은닉층에서 사용할 유닛수의 기본값 : 100
# 데이터가 매우 적은 상태이므로 100개를 쓰는 것보다는 줄이는 것이 좋다.
# 은닉유닛을 줄이면 모델의 복잡도는 낮아진다.
print(model.score(X_train,y_train))
print(model.score(X_test,y_test))
# Out:
# 0.925
# 0.9

# %%
from matplotlib import pyplot as plt
#한글 처리를 위해 폰트 설정
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

mglearn.plots.plot_2d_separator(model, X_train, fill=True, alpha=.3)
mglearn.discrete_scatter(X_train[:, 0], X_train[:, 1], y_train)
plt.xlabel("특성 0")
plt.ylabel("특성 1")
# Out:
# Text(0, 0.5, '특성 1')

# %%
# 은닉유닛을 10개로 줄이고 테스트
model = MLPClassifier(random_state=0, hidden_layer_sizes=[10], max_iter=1000)
model.fit(X_train, y_train)

print(model.score(X_train,y_train))
print(model.score(X_test,y_test))
# Out:
# 0.85
# 0.85

# %%
mglearn.plots.plot_2d_separator(model, X_train, fill=True, alpha=.3)
mglearn.discrete_scatter(X_train[:, 0], X_train[:, 1], y_train)
plt.xlabel("특성 0")
plt.ylabel("특성 1")
# Out:
# Text(0, 0.5, '특성 1')

# %%
# 10개의 유닛으로 된 두개의 은닉층 [10, 10]
model = MLPClassifier(random_state=0, hidden_layer_sizes=[10 ,10], max_iter=5000)
model.fit(X_train, y_train)

print(model.score(X_train,y_train))
print(model.score(X_test,y_test))
# Out:
# 0.8375
# 0.85

# %%
mglearn.plots.plot_2d_separator(model, X_train, fill=True, alpha=.3)
mglearn.discrete_scatter(X_train[:, 0], X_train[:, 1], y_train)
plt.xlabel('특성 0')
plt.ylabel('특성 1')
# Out:
# Text(0, 0.5, '특성 1')

# %%
# 100개의 유닛으로 된 세 개의 은닉층 [100, 100, 100]
model = MLPClassifier(random_state=0, hidden_layer_sizes=[100, 100, 100], max_iter=5000)
model.fit(X_train, y_train)

print(model.score(X_train,y_train))
print(model.score(X_test,y_test))
# Out:
# 1.0
# 1.0

# %%
mglearn.plots.plot_2d_separator(model, X_train, fill=True, alpha=.3)
mglearn.discrete_scatter(X_train[:, 0], X_train[:, 1], y_train)
plt.xlabel('특성 0')
plt.ylabel('특성 1')
# Out:
# Text(0, 0.5, '특성 1')
